# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Import packages

# %%
import os
import itertools

import cv2
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
import missingno as msno
from plotly.subplots import make_subplots
import plotly.graph_objects as go
from plotly.offline import iplot

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras import regularizers
from keras.callbacks import EarlyStopping, LearningRateScheduler
import numpy as np
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.efficientnet import preprocess_input

# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")

print ('modules loaded')
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# modules loaded

# %% [markdown]
# # EDA

# %%
train_data_dir = '/kaggle/input/pets-facial-expression-dataset/Master Folder/train'
valid_data_dir = '/kaggle/input/pets-facial-expression-dataset/Master Folder/valid'
test_data_dir = '/kaggle/input/pets-facial-expression-dataset/Master Folder/test'

data_dir = '/kaggle/input/pets-facial-expression-dataset'


ds_name = 'Pets Facial Expression'

# %%
# Generate data paths with labels

def generate_data_paths(data_dir):
    
    filepaths = []
    labels = []

    folds = os.listdir(data_dir)
    for fold in folds:
        if fold == 'Master Folder':
            continue
            
        foldpath = os.path.join(data_dir, fold)
        filelist = os.listdir(foldpath)
        for file in filelist:
            fpath = os.path.join(foldpath, file)
            filepaths.append(fpath)
            labels.append(fold)
            
    return filepaths, labels


filepaths, labels = generate_data_paths(data_dir)

# %%
def create_df(filepaths, labels):

    Fseries = pd.Series(filepaths, name= 'filepaths')
    Lseries = pd.Series(labels, name='labels')
    df = pd.concat([Fseries, Lseries], axis= 1)
    return df

df = create_df(filepaths, labels)

# %%
df.head()
# Out:
#                                            filepaths labels
# 0  /kaggle/input/pets-facial-expression-dataset/O...  Other
# 1  /kaggle/input/pets-facial-expression-dataset/O...  Other
# 2  /kaggle/input/pets-facial-expression-dataset/O...  Other
# 3  /kaggle/input/pets-facial-expression-dataset/O...  Other
# 4  /kaggle/input/pets-facial-expression-dataset/O...  Other

# %%
def num_of_examples(df, name='df'):
    print(f"The {name} dataset has {df.shape[0]} images.")
    
num_of_examples(df, ds_name)
# Out:
# The Pets Facial Expression dataset has 1000 images.

# %%
def num_of_classes(df, name='df'):
    print(f"The {name} dataset has {len(df['labels'].unique())} classes")
    
num_of_classes(df, ds_name)
# Out:
# The Pets Facial Expression dataset has 4 classes

# %%
def classes_count(df, name='df'):
    
    print(f"The {name} dataset has: ")
    print("="*70)
    print()
    for name in df['labels'].unique():
        num_class = len(df['labels'][df['labels'] == name])
        print(f"Class '{name}' has {num_class} images")
        print('-'*70)
        
classes_count(df, ds_name)
# Out:
# The Pets Facial Expression dataset has:
# ======================================================================
#
# Class 'Other' has 250 images
# ----------------------------------------------------------------------
# Class 'Angry' has 250 images
# ----------------------------------------------------------------------
# Class 'Sad' has 250 images
# ----------------------------------------------------------------------
# Class 'happy' has 250 images
# ----------------------------------------------------------------------

# %%
def cat_summary_with_graph(dataframe, col_name):
    fig = make_subplots(rows=1, cols=2,
                        subplot_titles=('Countplot', 'Percentages'),
                        specs=[[{"type": "xy"}, {'type': 'domain'}]])

    fig.add_trace(go.Bar(y=dataframe[col_name].value_counts().values.tolist(),
                         x=[str(i) for i in dataframe[col_name].value_counts().index],
                         text=dataframe[col_name].value_counts().values.tolist(),
                         textfont=dict(size=15),
                         name=col_name,
                         textposition='auto',
                         showlegend=False,
                         marker=dict(color=colors,
                                     line=dict(color='#DBE6EC',
                                               width=1))),
                  row=1, col=1)

    fig.add_trace(go.Pie(labels=dataframe[col_name].value_counts().keys(),
                         values=dataframe[col_name].value_counts().values,
                         textfont=dict(size=20),
                         textposition='auto',
                         showlegend=False,
                         name=col_name,
                         marker=dict(colors=colors)),
                  row=1, col=2)

    fig.update_layout(title={'text': col_name,
                             'y': 0.9,
                             'x': 0.5,
                             'xanchor': 'center',
                             'yanchor': 'top'},
                      template='plotly_white')

    iplot(fig)
    
    
colors = ['#494BD3', '#E28AE2', '#F1F481', '#79DB80', '#DF5F5F',
              '#69DADE', '#C2E37D', '#E26580', '#D39F49', '#B96FE3']

cat_summary_with_graph(df,'labels')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="1f2925b4-f3d0-475f-8cf2-41220d4a95b6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1f2925b4-f3d0-475f-8cf2-41220d4a95b6")) {                    Plotly.newPlot(                        "1f2925b4-f3d0-475f-8cf2-41220d4a95b6",                        [{"marker":{"color":["#494BD3","#E28AE2","#F1F481","#79DB80","#DF5F5F","#69DADE","#C2E37D","#E26580","#D39F49","#B96FE3"],"line":{"color":"#DBE6EC","width":1}},"name":"labels","showlegend":false,"text":["250","250","250","250"],"textfont":{"size":15},"textposition":"auto","x":["Other","Angry","Sad","happy"],"xaxis":"x","y":[250,250,250,250],"yaxis":"y","type":"bar"},{"domain":{"x":[0.55,1.0],"y":[0.0,1.0]},"labels":["Other","Angry","Sad","happy"],"marker":{"colors":["#494BD3","#E28AE2","#F1F481","#79DB80","#DF5F5F","#69DADE","#C2E37D","#E26580","#D39F49","#B96FE3"]},"name":"labels","showlegend":false,"textfont":{"size":20},"textposition":"auto","values":[250,250,250,250],"type":"pie"}],                        {"annotations":[{"font":{"size":16},"showarrow":false,"text":"Countplot","x":0.225,"xanchor":"center","xref":"paper","y":1.0,"yanchor":"bottom","yref":"paper"},{"font":{"size":16},"showarrow":false,"text":"Percentages","x":0.775,"xanchor":"center","xref":"paper","y":1.0,"yanchor":"bottom","yref":"paper"}],"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a ...

# %%
def check_null_values(df, name='df'):
    num_null_vals = sum(df.isnull().sum().values)
    
    if not num_null_vals:
        print(f"The {name} dataset has no null values")
    
    else:
        print(f"The {name} dataset has {num_null_vals} null values")
        print('-'*70)
        print('Total null values in each column:\n')
        print(df.isnull().sum())
        

check_null_values(df, ds_name)
# Out:
# The Pets Facial Expression dataset has no null values

# %% [markdown]
# # Visualise null vlaues

# %%
msno.matrix(df)
plt.title('Distribution of Missing Values', fontsize=30, fontstyle='oblique');

# %% [markdown]
# # Splitting

# %%
# train dataframe
train_df, dummy_df = train_test_split(df,  train_size= 0.8, shuffle= True, random_state= 123)

# valid and test dataframe
valid_df, test_df = train_test_split(dummy_df,  train_size= 0.6, shuffle= True, random_state= 123)

# %%
num_of_examples(train_df, "Training "+ds_name)
num_of_examples(valid_df, "Validation "+ds_name)
num_of_examples(test_df, "Testing "+ds_name)
# Out:
# The Training Pets Facial Expression dataset has 800 images.
# The Validation Pets Facial Expression dataset has 120 images.
# The Testing Pets Facial Expression dataset has 80 images.

# %%
num_of_classes(train_df, "Training "+ds_name)
num_of_classes(valid_df, "Validation "+ds_name)
num_of_classes(test_df, "Testing "+ds_name)
# Out:
# The Training Pets Facial Expression dataset has 4 classes
# The Validation Pets Facial Expression dataset has 4 classes
# The Testing Pets Facial Expression dataset has 4 classes

# %%
classes_count(train_df, 'Training '+ds_name)
# Out:
# The Training Pets Facial Expression dataset has:
# ======================================================================
#
# Class 'Sad' has 209 images
# ----------------------------------------------------------------------
# Class 'happy' has 192 images
# ----------------------------------------------------------------------
# Class 'Angry' has 201 images
# ----------------------------------------------------------------------
# Class 'Other' has 198 images
# ----------------------------------------------------------------------

# %%
classes_count(valid_df, 'Validation '+ds_name)
# Out:
# The Validation Pets Facial Expression dataset has:
# ======================================================================
#
# Class 'Angry' has 29 images
# ----------------------------------------------------------------------
# Class 'Sad' has 28 images
# ----------------------------------------------------------------------
# Class 'Other' has 35 images
# ----------------------------------------------------------------------
# Class 'happy' has 28 images
# ----------------------------------------------------------------------

# %%
classes_count(test_df, 'Testing '+ds_name)
# Out:
# The Testing Pets Facial Expression dataset has:
# ======================================================================
#
# Class 'Other' has 17 images
# ----------------------------------------------------------------------
# Class 'Angry' has 20 images
# ----------------------------------------------------------------------
# Class 'happy' has 30 images
# ----------------------------------------------------------------------
# Class 'Sad' has 13 images
# ----------------------------------------------------------------------

# %% [markdown]
# # Image Data Generator

# %%
# crobed image size
batch_size = 16
img_size = (224, 224)
channels = 3
img_shape = (img_size[0], img_size[1], channels)

# Recommended : use custom function for test data batch size, else we can use normal batch size.
ts_length = len(test_df)
test_batch_size = max(sorted([ts_length // n for n in range(1, ts_length + 1) if ts_length%n == 0 and ts_length/n <= 80]))
test_steps = ts_length // test_batch_size

# This function which will be used in image data generator for data augmentation, it just take the image and return it again.
def scalar(img):
    return img

tr_gen = ImageDataGenerator(preprocessing_function= scalar,
                           rotation_range=40,
                           width_shift_range=0.2,
                           height_shift_range=0.2,
                           brightness_range=[0.4,0.6],
                           zoom_range=0.3,
                           horizontal_flip=True,
                           vertical_flip=True)

ts_gen = ImageDataGenerator(preprocessing_function= scalar,
                           rotation_range=40,
                           width_shift_range=0.2,
                           height_shift_range=0.2,
                           brightness_range=[0.4,0.6],
                           zoom_range=0.3,
                           horizontal_flip=True,
                           vertical_flip=True)

train_gen = tr_gen.flow_from_dataframe(train_df, 
                                       x_col= 'filepaths', 
                                       y_col= 'labels', 
                                       target_size= img_size, 
                                       class_mode= 'categorical',
                                       color_mode= 'rgb', 
                                       shuffle= True, 
                                       batch_size= batch_size)

valid_gen = ts_gen.flow_from_dataframe(valid_df, 
                                       x_col= 'filepaths', 
                                       y_col= 'labels', 
                                       target_size= img_size, 
                                       class_mode= 'categorical',
                                       color_mode= 'rgb', 
                                       shuffle= True, 
                                       batch_size= batch_size)

# Note: we will use custom test_batch_size, and make shuffle= false
test_gen = ts_gen.flow_from_dataframe(test_df, 
                                      x_col= 'filepaths', 
                                      y_col= 'labels', 
                                      target_size= img_size, 
                                      class_mode= 'categorical',
                                      color_mode= 'rgb', 
                                      shuffle= False, 
                                      batch_size= test_batch_size)
# Out:
# Found 800 validated image filenames belonging to 4 classes.
# Found 120 validated image filenames belonging to 4 classes.
# Found 80 validated image filenames belonging to 4 classes.

# %% [markdown]
# # Visualize data

# %%
g_dict = train_gen.class_indices      # defines dictionary {'class': index}
classes = list(g_dict.keys())       # defines list of dictionary's kays (classes), classes names : string
images, labels = next(train_gen)      # get a batch size samples from the generator

plt.figure(figsize= (20, 20))

for i in range(16):
    plt.subplot(4, 4, i + 1)
    image = images[i] / 255       # scales data to range (0 - 255)
    plt.imshow(image)
    index = np.argmax(labels[i])  # get image index
    class_name = classes[index]   # get class of image
    plt.title(class_name, color= 'blue', fontsize= 12)
    plt.axis('off')
    
plt.show()

# %% [markdown]
# # Model

# %%
# Create Model Structure
img_size = (224, 224)
channels = 3
img_shape = (img_size[0], img_size[1], channels)
class_count = len(list(train_gen.class_indices.keys())) # to define number of classes in dense layer

# create pre-trained model (you can built on pretrained model such as :  efficientnet, VGG , Resnet )
# we will use efficientnetb3 from EfficientNet family.
base_model = tf.keras.applications.efficientnet.EfficientNetB5(include_top= False, weights= "imagenet", input_shape= img_shape, pooling= 'max')
base_model.trainable = False

model = Sequential([
    base_model,
    BatchNormalization(axis= -1, momentum= 0.99, epsilon= 0.001),
    Dense(256, activation='relu'),
    Dense(128, kernel_regularizer= regularizers.l2(l= 0.016), activity_regularizer= regularizers.l1(0.006),
                bias_regularizer= regularizers.l1(0.006), activation= 'relu'),
    Dropout(rate= 0.45, seed= 123),
    Dense(class_count, activation= 'softmax')
])

model.compile(Adamax(learning_rate= 0.001), loss= 'categorical_crossentropy', metrics= ['accuracy'])

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb5_notop.h5
# 115263384/115263384 [==============================] - 1s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb5 (Functional)  (None, 2048)             28513527
#
#  batch_normalization (BatchN  (None, 2048)             8192
#  ormalization)
#
#  dense (Dense)               (None, 256)               524544
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_2 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 29,079,675
# Trainable params: 562,052
# Non-trainable params: 28,517,623
# _________________________________________________________________

# %% [markdown]
# # Callbacks

# %%
early_stopping = EarlyStopping(monitor='val_accuracy', 
                               patience=5, 
                               restore_best_weights=True,
                               mode='max',
                              )

def step_decay(epoch):
    
     initial_lrate = 0.1
     drop = 0.5
     epochs_drop = 10.0
     lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
     return lrate

lr_scheduler = LearningRateScheduler(step_decay)

# %% [markdown]
# # Training

# %%
batch_size = 16   # set batch size for training
epochs = 100   # number of all epochs in training

history = model.fit(x=train_gen,
                    epochs= epochs,
                    verbose= 1,
                    validation_data= valid_gen, 
                    validation_steps= None,
                    shuffle= False,
                    callbacks = [early_stopping,step_decay(epochs),lr_scheduler])
# Out:
# Epoch 1/100
# 2023-09-04 05:55:16.162432: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential/efficientnetb5/block1b_drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 50/50 [==============================] - 45s 447ms/step - loss: 4.3550 - accuracy: 0.3800 - val_loss: 4.7484 - val_accuracy: 0.4000
# Epoch 2/100
# 50/50 [==============================] - 14s 287ms/step - loss: 3.8234 - accuracy: 0.4825 - val_loss: 3.5468 - val_accuracy: 0.5750
# Epoch 3/100
# 50/50 [==============================] - 14s 272ms/step - loss: 3.5271 - accuracy: 0.5163 - val_loss: 3.3831 - val_accuracy: 0.6167
# Epoch 4/100
# 50/50 [==============================] - 14s 285ms/step - loss: 3.3273 - accuracy: 0.5763 - val_loss: 3.1616 - val_accuracy: 0.5917
# Epoch 5/100
# 50/50 [==============================] - 14s 270ms/step - loss: 3.1488 - accuracy: 0.6037 - val_loss: 2.9967 - val_accuracy: 0.6583
# Epoch 6/100
# 50/50 [==============================] - 14s 289ms/step - loss: 2.9621 - accuracy: 0.6288 - val_loss: 2.8915 - val_accuracy: 0.6250
# Epoch 7/100
# 50/50 [==============================] - 14s 275ms/step - loss: 2.8487 - accuracy: 0.6500 - val_loss: 2.7388 - val_accuracy: 0.6750
# Epoch 8/100
# 50/50 [==============================] - 14s 287ms/step - loss: 2.7096 - accuracy: 0.6737 - val_loss: 2.7382 - val_accuracy: 0.6083
# Epoch 9/100
# 50/50 [==============================] - 14s 271ms/step - loss: 2.5889 - accuracy: 0.6875 - val_loss: 2.6447 - val_accuracy: 0.6500
# Epoch 10/100
# 50/50 [==============================] - 14s 287ms/step - loss: 2.4716 - accuracy: 0.6925 - val_loss: 2.4627 - val_accuracy: 0.7083
# Epoch 11/100
# 50/50 [==============================] - 13s 269ms/step - loss: 2.3893 - accuracy: 0.7063 - val_loss: 2.3885 - val_accuracy: 0.7417
# Epoch 12/100
# 50/50 [==============================] - 14s 288ms/step - loss: 2.3002 - accuracy: 0.7163 - val_loss: 2.3337 - val_accuracy: 0.6833
# Epoch 13/100
# 50/50 [==============================] - 14s 271ms/step - loss: 2.2019 - accuracy: 0.7350 - val_loss: 2.2788 - val_accuracy: 0.7083
# Epoch 14/100
# 50/50 [==============================] - 14s 288ms/step - loss: 2.0965 - accuracy: 0.7425 - val_loss: 2.1483 - val_accuracy: 0.7750
# Epoch 15/100
# 50/50 [==============================] - 14s 285ms/step - loss: 2.0828 - accuracy: 0.7050 - val_loss: 2.1042 - val_accuracy: 0.6750
# Epoch 16/100
# 50/50 [==============================] - 14s 270ms/step - loss: 1.9595 - accuracy: 0.7563 - val_loss: 1.9180 - val_accuracy: 0.7500
# Epoch 17/100
# 50/50 [==============================] - 14s 272ms/step - loss: 1.8704 - accuracy: 0.7850 - val_loss: 1.9729 - val_accuracy: 0.7167
# Epoch 18/100
# 50/50 [==============================] - 14s 285ms/step - loss: 1.8619 - accuracy: 0.7513 - val_loss: 1.8604 - val_accuracy: 0.7583
# Epoch 19/100
# 50/50 [==============================] - 14s 278ms/step - loss: 1.7667 - accuracy: 0.7987 - val_loss: 1.7743 - val_accuracy: 0.7833
# Epoch 20/100
# 50/50 [==============================] - 14s 273ms/step - loss: 1.7106 - accuracy: 0.7912 - val_loss: 1.7288 - val_accuracy: 0.7333
# Epoch 21/100
# 50/50 [==============================] - 15s 290ms/step - loss: 1.6583 - accuracy: 0.7763 - val_loss: 1.6141 - val_accuracy: 0.8083
# Epoch 22/100
# 50/50 [==============================] - 14s 271ms/step - loss: 1.5884 - accuracy: 0.8037 - val_loss: 1.6516 - val_accuracy: 0.7917
# Epoch 23/100
# 50/50 [==============================] - 15s 291ms/step - loss: 1.5645 - accuracy: 0.8062 - val_loss: 1.5539 - val_accuracy: 0.7667
# Epoch 24/100
# 50/50 [==============================] - 14s 272ms/step - loss: 1.4688 - accuracy: 0.8338 - val_loss: 1.5445 - val_accuracy: 0.8000
# Epoch 25/100
# 50/50 [==============================] - 14s 287ms/step - loss: 1.4141 - accuracy: 0.8388 - val_loss: 1.5418 - val_accuracy: 0.7667
# Epoch 26/100
# 50/50 [==============================] - 14s 272ms/step - loss: 1.4276 - accuracy: 0.8350 - val_loss: 1.4779 - val_accuracy: 0.7833
# Epoch 27/100
# 50/50 [==============================] - 14s 270ms/step - loss: 1.3762 - accuracy: 0.8250 - val_loss: 1.3777 - val_accuracy: 0.8333
# Epoch 28/100
# 50/50 [==============================] - 14s 287ms/step - loss: 1.3569 - accuracy: 0.8338 - val_loss: 1.4030 - val_accuracy: 0.8250
# Epoch 29/100
# 50/50 [==============================] - 14s 272ms/step - loss: 1.2903 - accuracy: 0.8388 - val_loss: 1.3202 - val_accuracy: 0.8250
# Epoch 30/100
# 50/50 [==============================] - 14s 284ms/step - loss: 1.2474 - accuracy: 0.8537 - val_loss: 1.2819 - val_accuracy: 0.8000
# Epoch 31/100
# 50/50 [==============================] - 14s 270ms/step - loss: 1.2513 - accuracy: 0.8400 - val_loss: 1.3070 - val_accuracy: 0.8667
# Epoch 32/100
# 50/50 [==============================] - 14s 284ms/step - loss: 1.1904 - accuracy: 0.8550 - val_loss: 1.2471 - val_accuracy: 0.8250
# Epoch 33/100
# 50/50 [==============================] - 13s 269ms/step - loss: 1.1536 - accuracy: 0.8775 - val_loss: 1.2712 - val_accuracy: 0.8000
# Epoch 34/100
# 50/50 [==============================] - 14s 285ms/step - loss: 1.1186 - accuracy: 0.8687 - val_loss: 1.2464 - val_accuracy: 0.7917
# Epoch 35/100
# 50/50 [==============================] - 13s 269ms/step - loss: 1.0902 - accuracy: 0.8587 - val_loss: 1.1246 - val_accuracy: 0.8750
# Epoch 36/100
# 50/50 [==============================] - 14s 285ms/step - loss: 1.1006 - accuracy: 0.8575 - val_loss: 1.1734 - val_accuracy: 0.8167
# Epoch 37/100
# 50/50 [==============================] - 13s 268ms/step - loss: 1.0635 - accuracy: 0.8687 - val_loss: 1.0824 - val_accuracy: 0.8667
# Epoch 38/100
# 50/50 [==============================] - 14s 285ms/step - loss: 1.0339 - accuracy: 0.8612 - val_loss: 1.1069 - val_accuracy: 0.8250
# Epoch 39/100
# 50/50 [==============================] - 13s 269ms/step - loss: 1.0243 - accuracy: 0.8650 - val_loss: 1.1088 - val_accuracy: 0.8333
# Epoch 40/100
# 50/50 [==============================] - 14s 287ms/step - loss: 1.0351 - accuracy: 0.8600 - val_loss: 0.9901 - val_accuracy: 0.8750
# Epoch 41/100
# 50/50 [==============================] - 14s 273ms/step - loss: 0.9803 - accuracy: 0.8712 - val_loss: 1.0244 - val_accuracy: 0.8667
# Epoch 42/100
# 50/50 [==============================] - 14s 286ms/step - loss: 0.9536 - accuracy: 0.8888 - val_loss: 1.0220 - val_accuracy: 0.8250
# Epoch 43/100
# 50/50 [==============================] - 14s 271ms/step - loss: 0.9398 - accuracy: 0.8888 - val_loss: 0.9848 - val_accuracy: 0.8667
# Epoch 44/100
# 50/50 [==============================] - 14s 288ms/step - loss: 0.8787 - accuracy: 0.9112 - val_loss: 0.9627 - val_accuracy: 0.8917
# Epoch 45/100
# 50/50 [==============================] - 14s 278ms/step - loss: 0.8895 - accuracy: 0.8963 - val_loss: 1.0377 - val_accuracy: 0.8500
# Epoch 46/100
# 50/50 [==============================] - 14s 271ms/step - loss: 0.8888 - accuracy: 0.8750 - val_loss: 1.0739 - val_accuracy: 0.7917
# Epoch 47/100
# 50/50 [==============================] - 14s 288ms/step - loss: 0.8519 - accuracy: 0.8963 - val_loss: 0.9168 - val_accuracy: 0.8417
# Epoch 48/100
# 50/50 [==============================] - 14s 270ms/step - loss: 0.8154 - accuracy: 0.9137 - val_loss: 1.0276 - val_accuracy: 0.8500
# Epoch 49/100
# 50/50 [==============================] - 14s 289ms/step - loss: 0.8422 - accuracy: 0.8875 - val_loss: 0.9080 - val_accuracy: 0.8500
# Epoch 50/100
# 50/50 [==============================] - 14s 271ms/step - loss: 0.8233 - accuracy: 0.8925 - val_loss: 0.9186 - val_accuracy: 0.8667
# Epoch 51/100
# 50/50 [==============================] - 15s 291ms/step - loss: 0.8331 - accuracy: 0.8913 - val_loss: 0.8479 - val_accuracy: 0.9000
# Epoch 52/100
# 50/50 [==============================] - 14s 275ms/step - loss: 0.7467 - accuracy: 0.9200 - val_loss: 0.8871 - val_accuracy: 0.8917
# Epoch 53/100
# 50/50 [==============================] - 15s 290ms/step - loss: 0.7290 - accuracy: 0.9275 - val_loss: 0.8004 - val_accuracy: 0.8917
# Epoch 54/100
# 50/50 [==============================] - 14s 278ms/step - loss: 0.7425 - accuracy: 0.9237 - val_loss: 0.8194 - val_accuracy: 0.8833
# Epoch 55/100
# 50/50 [==============================] - 14s 288ms/step - loss: 0.7158 - accuracy: 0.9262 - val_loss: 0.7751 - val_accuracy: 0.8583
# Epoch 56/100
# 50/50 [==============================] - 14s 289ms/step - loss: 0.7045 - accuracy: 0.9262 - val_loss: 0.8058 - val_accuracy: 0.8667
# Epoch 57/100
# 50/50 [==============================] - 14s 279ms/step - loss: 0.7354 - accuracy: 0.9112 - val_loss: 0.7795 - val_accuracy: 0.8917
# Epoch 58/100
# 50/50 [==============================] - 15s 296ms/step - loss: 0.7062 - accuracy: 0.9200 - val_loss: 0.7666 - val_accuracy: 0.8833
# Epoch 59/100
# 50/50 [==============================] - 14s 275ms/step - loss: 0.6781 - accuracy: 0.9137 - val_loss: 0.7832 - val_accuracy: 0.8833
# Epoch 60/100
# 50/50 [==============================] - 15s 292ms/step - loss: 0.6741 - accuracy: 0.9225 - val_loss: 0.7033 - val_accuracy: 0.9000
# Epoch 61/100
# 50/50 [==============================] - 15s 292ms/step - loss: 0.6528 - accuracy: 0.9300 - val_loss: 0.6867 - val_accuracy: 0.9167
# Epoch 62/100
# 50/50 [==============================] - 14s 278ms/step - loss: 0.6508 - accuracy: 0.9325 - val_loss: 0.7441 - val_accuracy: 0.8917
# Epoch 63/100
# 50/50 [==============================] - 15s 291ms/step - loss: 0.6408 - accuracy: 0.9212 - val_loss: 0.7200 - val_accuracy: 0.8833
# Epoch 64/100
# 50/50 [==============================] - 14s 282ms/step - loss: 0.6355 - accuracy: 0.9262 - val_loss: 0.7072 - val_accuracy: 0.9167
# Epoch 65/100
# 50/50 [==============================] - 15s 300ms/step - loss: 0.6179 - accuracy: 0.9187 - val_loss: 0.6373 - val_accuracy: 0.9167
# Epoch 66/100
# 50/50 [==============================] - 14s 279ms/step - loss: 0.6063 - accuracy: 0.9300 - val_loss: 0.6495 - val_accuracy: 0.8833
# Epoch 67/100
# 50/50 [==============================] - 14s 279ms/step - loss: 0.5901 - accuracy: 0.9262 - val_loss: 0.6906 - val_accuracy: 0.8917
# Epoch 68/100
# 50/50 [==============================] - 14s 278ms/step - loss: 0.6130 - accuracy: 0.9225 - val_loss: 0.6612 - val_accuracy: 0.9167
# Epoch 69/100
# 50/50 [==============================] - 15s 293ms/step - loss: 0.5714 - accuracy: 0.9362 - val_loss: 0.6568 - val_accuracy: 0.8750
# Epoch 70/100
# 50/50 [==============================] - 15s 292ms/step - loss: 0.5887 - accuracy: 0.9250 - val_loss: 0.6254 - val_accuracy: 0.8833
# Epoch 71/100
# 50/50 [==============================] - 14s 278ms/step - loss: 0.5672 - accuracy: 0.9250 - val_loss: 0.6845 - val_accuracy: 0.8917
# Epoch 72/100
# 50/50 [==============================] - 15s 292ms/step - loss: 0.5633 - accuracy: 0.9400 - val_loss: 0.5850 - val_accuracy: 0.9000
# Epoch 73/100
# 50/50 [==============================] - 15s 294ms/step - loss: 0.5705 - accuracy: 0.9250 - val_loss: 0.6354 - val_accuracy: 0.8833
# Epoch 74/100
# 50/50 [==============================] - 14s 282ms/step - loss: 0.5364 - accuracy: 0.9362 - val_loss: 0.6185 - val_accuracy: 0.9333
# Epoch 75/100
# 50/50 [==============================] - 15s 294ms/step - loss: 0.5210 - accuracy: 0.9475 - val_loss: 0.7006 - val_accuracy: 0.9000
# Epoch 76/100
# 50/50 [==============================] - 14s 278ms/step - loss: 0.5322 - accuracy: 0.9388 - val_loss: 0.5936 - val_accuracy: 0.9250
# Epoch 77/100
# 50/50 [==============================] - 15s 296ms/step - loss: 0.5327 - accuracy: 0.9350 - val_loss: 0.5513 - val_accuracy: 0.9083
# Epoch 78/100
# 50/50 [==============================] - 14s 276ms/step - loss: 0.5235 - accuracy: 0.9337 - val_loss: 0.5755 - val_accuracy: 0.9250
# Epoch 79/100
# 50/50 [==============================] - 14s 279ms/step - loss: 0.4960 - accuracy: 0.9400 - val_loss: 0.5938 - val_accuracy: 0.9083
# Epoch 80/100
# 50/50 [==============================] - 15s 292ms/step - loss: 0.5041 - accuracy: 0.9475 - val_loss: 0.7192 - val_accuracy: 0.8500
# Epoch 81/100
# 50/50 [==============================] - 14s 279ms/step - loss: 0.4876 - accuracy: 0.9362 - val_loss: 0.5923 - val_accuracy: 0.8833
# Epoch 82/100
# 50/50 [==============================] - 14s 279ms/step - loss: 0.4981 - accuracy: 0.9400 - val_loss: 0.5711 - val_accuracy: 0.9000
# Epoch 83/100
# 50/50 [==============================] - 14s 277ms/step - loss: 0.4560 - accuracy: 0.9538 - val_loss: 0.5838 - val_accuracy: 0.9250
# Epoch 84/100
# 50/50 [==============================] - 14s 277ms/step - loss: 0.4843 - accuracy: 0.9425 - val_loss: 0.5481 - val_accuracy: 0.9000
# Epoch 85/100
# 50/50 [==============================] - 15s 297ms/step - loss: 0.4732 - accuracy: 0.9488 - val_loss: 0.5246 - val_accuracy: 0.9000
# Epoch 86/100
# 50/50 [==============================] - 14s 276ms/step - loss: 0.4707 - accuracy: 0.9400 - val_loss: 0.6127 - val_accuracy: 0.9167
# Epoch 87/100
# 50/50 [==============================] - 14s 289ms/step - loss: 0.4450 - accuracy: 0.9475 - val_loss: 0.5755 - val_accuracy: 0.9250
# Epoch 88/100
# 50/50 [==============================] - 14s 276ms/step - loss: 0.4610 - accuracy: 0.9388 - val_loss: 0.5900 - val_accuracy: 0.9083
# Epoch 89/100
# 50/50 [==============================] - 15s 292ms/step - loss: 0.4576 - accuracy: 0.9438 - val_loss: 0.5168 - val_accuracy: 0.9333
# Epoch 90/100
# 50/50 [==============================] - 14s 277ms/step - loss: 0.4423 - accuracy: 0.9563 - val_loss: 0.5603 - val_accuracy: 0.9083
# Epoch 91/100
# 50/50 [==============================] - 15s 294ms/step - loss: 0.4413 - accuracy: 0.9488 - val_loss: 0.5095 - val_accuracy: 0.9250
# Epoch 92/100
# 50/50 [==============================] - 15s 291ms/step - loss: 0.4463 - accuracy: 0.9400 - val_loss: 0.5430 - val_accuracy: 0.8917
# Epoch 93/100
# 50/50 [==============================] - 14s 276ms/step - loss: 0.4383 - accuracy: 0.9463 - val_loss: 0.5312 - val_accuracy: 0.9167
# Epoch 94/100
# 50/50 [==============================] - 14s 275ms/step - loss: 0.4218 - accuracy: 0.9463 - val_loss: 0.4891 - val_accuracy: 0.9167
# Epoch 95/100
# 50/50 [==============================] - 15s 291ms/step - loss: 0.4424 - accuracy: 0.9375 - val_loss: 0.4524 - val_accuracy: 0.9250
# Epoch 96/100
# 50/50 [==============================] - 14s 288ms/step - loss: 0.4250 - accuracy: 0.9500 - val_loss: 0.4850 - val_accuracy: 0.9000
# Epoch 97/100
# 50/50 [==============================] - 14s 283ms/step - loss: 0.4051 - accuracy: 0.9538 - val_loss: 0.5804 - val_accuracy: 0.8917
# Epoch 98/100
# 50/50 [==============================] - 15s 292ms/step - loss: 0.3993 - accuracy: 0.9500 - val_loss: 0.4712 - val_accuracy: 0.9250
# Epoch 99/100
# 50/50 [==============================] - 14s 277ms/step - loss: 0.4110 - accuracy: 0.9513 - val_loss: 0.4858 - val_accuracy: 0.9167
# Epoch 100/100
# 50/50 [==============================] - 15s 293ms/step - loss: 0.3954 - accuracy: 0.9550 - val_loss: 0.4089 - val_accuracy: 0.9417

# %% [markdown]
# # Evaluate model

# %%
# Define needed variables
tr_acc = history.history['accuracy']
tr_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmax(val_acc)
acc_highest = val_acc[index_acc]
Epochs = [i+1 for i in range(len(tr_acc))]
loss_label = f'best epoch= {str(index_loss + 1)}'
acc_label = f'best epoch= {str(index_acc + 1)}'

# Plot training history

plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout
plt.show()

# %%
ts_length = len(test_df)
test_batch_size = max(sorted([ts_length // n for n in range(1, ts_length + 1) if ts_length%n == 0 and ts_length/n <= 80]))
test_steps = ts_length // test_batch_size

train_score = model.evaluate(train_gen, steps= test_steps, verbose= 1)
valid_score = model.evaluate(valid_gen, steps= test_steps, verbose= 1)
test_score = model.evaluate(test_gen, steps= test_steps, verbose= 1)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
# Out:
# 1/1 [==============================] - 0s 317ms/step - loss: 0.2727 - accuracy: 1.0000
# 1/1 [==============================] - 0s 306ms/step - loss: 0.3470 - accuracy: 0.9375
# 1/1 [==============================] - 3s 3s/step - loss: 0.4115 - accuracy: 0.9250
# Train Loss:  0.27273932099342346
# Train Accuracy:  1.0
# --------------------
# Test Loss:  0.41147294640541077
# Test Accuracy:  0.925000011920929

# %% [markdown]
# # Get Prediction

# %%
preds = model.predict_generator(test_gen)
y_pred = np.argmax(preds, axis=1)

# %%
g_dict = test_gen.class_indices
classes = list(g_dict.keys())

# Confusion matrix
cm = confusion_matrix(test_gen.classes, y_pred)

plt.figure(figsize= (10, 10))
plt.imshow(cm, interpolation= 'nearest', cmap= plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation= 45)
plt.yticks(tick_marks, classes)


thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j], horizontalalignment= 'center', color= 'white' if cm[i, j] > thresh else 'black')

plt.tight_layout()
plt.ylabel('True Label')
plt.xlabel('Predicted Label')

plt.show()

# %%
# Classification report
print(classification_report(test_gen.classes, y_pred, target_names= classes))
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.89      0.85      0.87        20
#        Other       0.84      0.94      0.89        17
#          Sad       0.81      1.00      0.90        13
#        happy       1.00      0.87      0.93        30
#
#     accuracy                           0.90        80
#    macro avg       0.89      0.91      0.90        80
# weighted avg       0.91      0.90      0.90        80

# %% [markdown]
# # Save the model

# %%
model.save_weights('EfficientPet.h5')

# %% [markdown]
# # Load model and Predict

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.efficientnet import preprocess_input

def predict_and_display(image_path, model):
    
    img = image.load_img(image_path, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = preprocess_input(img_array)

    prediction = model.predict(img_array)
    predicted_class_index = np.argmax(prediction)
    
    class_indices = train_gen.class_indices
    class_labels = list(class_indices.keys())
    predicted_class_label = class_labels[predicted_class_index]
    
    plt.imshow(img)
    plt.axis('off')
    if predicted_class_label == 'Other':
        plt.title(f"The pet is normal")
    else:
        plt.title(f"The Pet is {predicted_class_label}")
    plt.show()

model.load_weights('/kaggle/working/EfficientPet.h5')

class_labels = ['Angry', 'Other', 'Sad', 'Happy']

# Replace 'path_to_test_image' with the path to the image you want to test
image_path_to_test = '/kaggle/input/pets-facial-expression-dataset/Angry/04.jpg'
predict_and_display(image_path_to_test, model)
# Out:
# 1/1 [==============================] - 0s 38ms/step
